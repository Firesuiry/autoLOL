# %%
import matplotlib.pyplot as plt
import cv2

# %%
i= 0
lable = []
while True:
    pic = cv2.imread(r'{}.png'.format(i))
    if pic is None:
        break


    plt.imshow(pic)
    plt.show()
    print('label index:{}'.format(i))
    a = input("input:")
    lable.append(a)
    i+= 1
# Out:
# label index:0
# input:6
# label index:1
# input:9
# label index:2
# input:5
# label index:3
# input:5
# label index:4
# input:9
# label index:5
# input:6
# label index:6
# input:7
# label index:7
# input:6
# label index:8
# input:6
# label index:9
# input:2
# label index:10
# input:0
# label index:11
# input:9
# label index:12
# input:4
# label index:13
# input:1
# label index:14
# input:3
# label index:15
# input:6
# label index:16
# input:6
# label index:17
# input:3
# label index:18
# input:9
# label index:19
# input:2
# label index:20
# input:6
# label index:21
# input:8
# label index:22
# input:2
# label index:23
# input:9
# label index:24
# input:0
# label index:25
# input:3
# label index:26
# input:8
# label index:27
# input:0
# label index:28
# input:3
# label index:29
# input:4
# label index:30
# input:1
# label index:31
# input:1
# label index:32
# input:8
# label index:33
# input:4
# label index:34
# input:7
# label index:35
# input:7
# label index:36
# input:6
# ...

# %%
print(lable)
# Out:
# ['6', '9', '5', '5', '9', '6', '7', '6', '6', '2', '0', '9', '4', '1', '3', '6', '6', '3', '9', '2', '6', '8', '2', '9', '0', '3', '8', '0', '3', '4', '1', '1', '8', '4', '7', '7', '6', '9', '6', '6', '1', '0', '0', '1', '6', '1', '8', '1', '0', '0', '1', '3', '6', '4', '0', '4', '0', '2', '0', '4', '1', '4', '1', '1', '1', '1', '8', '7', '4', '3', '9', '9', '9', '1', '5', '9', '4', '1', '6', '7', '5', '5', '7', '8', '9', '3', '2', '2', '4', '6', '5', '5', '2', '2', '2', '3', '8', '4', '4', '3', '0', '6', '6', '8', '6', '6', '6', '8', '1', '6', '1', '8', '8', '6', '6', '6', '6']
